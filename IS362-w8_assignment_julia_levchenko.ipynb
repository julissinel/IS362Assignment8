# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set()

df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data',delim_whitespace=True,header=None)
df.columns=['MPG','Cylinders','Displacement','Horsepower','Weight','Acceleration','Model_Year','Origin','Car_Name']
df.set_index('Car_Name',inplace=True)
df.replace('?',np.nan,inplace=True)
df['Horsepower'] = pd.to_numeric(df['Horsepower'])
df['Origin'] = df['Origin'].replace([1,2,3],['USA','Asia','Europe'])
df
# Out:
#                             MPG  Cylinders  Displacement  Horsepower  Weight  \
# Car_Name
# chevrolet chevelle malibu  18.0          8         307.0       130.0  3504.0
# buick skylark 320          15.0          8         350.0       165.0  3693.0
# plymouth satellite         18.0          8         318.0       150.0  3436.0
# amc rebel sst              16.0          8         304.0       150.0  3433.0
# ford torino                17.0          8         302.0       140.0  3449.0
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0  2790.0
# vw pickup                  44.0          4          97.0        52.0  2130.0
# dodge rampage              32.0          4         135.0        84.0  2295.0
# ford ranger                28.0          4         120.0        79.0  2625.0
# chevy s-10                 31.0          4         119.0        82.0  2720.0
#
# ...

# %%
sns.distplot(df['Cylinders'], kde=False)

# %%
sns.scatterplot(x=df['Horsepower'], y=df['Weight'])

# %%
#question - what is the correkation between car horsepower value and MPG?
sns.catplot(data=df,kind='swarm',x='Horsepower', y='MPG')
